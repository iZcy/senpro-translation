# %%
# !pip install requests
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests, uuid, json

path_and_methods = [
    {
        "path": "/languages",
        "method_name": "get",
        "body": None,  # GET requests typically do not have a body
        "params": {
        }
    },
    {
        "path": "/translate",
        "method_name": "post",
        "body": [
            {"Text": "I would die every day waiting for you. Darling don’t be afraid, I have loved you for a thousand years. I’ll love you for a thousand more."}
        ],
        "params": {
            "to": ["id"]
        }
    },
    {
        "path": "/transliterate",
        "method_name": "post",
        "body": [
            {"Text": "こんにちは"}
        ],
        "params": {
            "language": "ja",
            "fromScript": "Jpan",
            "toScript": "Latn"
        }
    },
    {
        "path": "/detect",
        "method_name": "post",
        "body": [
            {"Text": "Bonjour"}
        ],
        "params": {
        }
    },
    {
        "path": "/breakSentence",
        "method_name": "post",
        "body": [
            {"Text": "Hello. How are you? I'm fine."}
        ],
        "params": {
        }
    },
    {
        "path": "/dictionary/lookup",
        "method_name": "post",
        "body": [
            {"Text": "example"}
        ],
        "params": {
            "from": "en",
            "to": "es"
        }
    },
    {
        "path": "/dictionary/examples",
        "method_name": "post",
        "body": [
            {
                "Text": "fly",
                "Translation": "volar"
            }
        ],
        "params": {
            "from": "en",
            "to": "es"
        }
    }
]


def useTranslator(path, method_name, body, params):
    # Add your key and endpoint
    key = "ETtCNPNr9tyLzHuTvcNlE1xffJp2nxlT8upQV4vccJlGVyx1hYvxJQQJ99BCACqBBLyXJ3w3AAAbACOGTlXB"
    endpoint = "https://api.cognitive.microsofttranslator.com"

    # location, also known as region.
    # required if you're using a multi-service or regional (not global) resource. It can be found in the Azure portal on the Keys and Endpoint page.
    location = "southeastasia"

    constructed_url = endpoint + path

    params['api-version'] = '3.0'

    headers = {
        'Ocp-Apim-Subscription-Key': key,
        # location required if you're using a multi-service or regional (not global) resource.
        'Ocp-Apim-Subscription-Region': location,
        'Content-type': 'application/json',
        'X-ClientTraceId': str(uuid.uuid4())
    }

    send_method = getattr(requests, method_name)

    request = send_method(constructed_url, params=params, headers=headers, json=body)
    response = request.json()
    # return json for request and response
    return_body = {
        'request': {
            'url': constructed_url,
            'method': method_name.upper(),
            'headers': headers,
            'body': body,
            'params': params
        },
        'response': response
    }

    return json.dumps(return_body, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': '))

for item in path_and_methods:
    # print(f"Calling {item['method_name'].upper()} {item['path']}...")
    # print calling type as json
    print(f"{'{\"cmd\": \"' + item['method_name'].upper()} {item['path'] + '\"}' }\n")

    response_data = useTranslator(item["path"], item["method_name"], item["body"], item['params'])
    
    print(response_data)  # Print API response
# Out:
# {"cmd": "GET /languages"}
#
# {
#     "request": {
#         "body": null,
#         "headers": {
#             "Content-type": "application/json",
#             "Ocp-Apim-Subscription-Key": "ETtCNPNr9tyLzHuTvcNlE1xffJp2nxlT8upQV4vccJlGVyx1hYvxJQQJ99BCACqBBLyXJ3w3AAAbACOGTlXB",
#             "Ocp-Apim-Subscription-Region": "southeastasia",
#             "X-ClientTraceId": "2605f178-e9a0-4527-8cd2-4e4f105c4912"
#         },
#         "method": "GET",
#         "params": {
#             "api-version": "3.0"
#         },
#         "url": "https://api.cognitive.microsofttranslator.com/languages"
#     },
#     "response": {
#         "dictionary": {
#             "af": {
#                 "dir": "ltr",
#                 "name": "Afrikaans",
#                 "nativeName": "Afrikaans",
#                 "translations": [
#                     {
#                         "code": "en",
#                         "dir": "ltr",
#                         "name": "English",
# ...
